# %%
# Ask the user for their name
name = input("Hello, what is your name? ")

# Print a greeting using the name they entered
print(f"Hello, {name}. Good to meet you!")
# Out:
# Hello, swoyam. Good to meet you!

# %%
# Ask the user to enter a temperature in Celsius
celsius = float(input("Enter a temperature in Celsius: "))

# Convert Celsius to Fahrenheit using the formula
fahrenheit = (celsius * 9 / 5) + 32

# Display the result
print(f"{celsius}C is equivalent to {fahrenheit}F.")
# Out:
# 12.0C is equivalent to 53.6F.

# %%
# Ask for the total number of students
students = int(input("How many students? "))

# Ask for the desired group size
group_size = int(input("Required group size? "))

# Calculate how many full groups are needed
groups = students // group_size

# Calculate how many students are left over
leftover = students % group_size

# Display the result with correct grammar
if leftover == 1:
    print(f"There will be {groups} groups with 1 student left over.")
else:
    print(f"There will be {groups} groups with {leftover} students left over.")
# Out:
# There will be 1 groups with 0 students left over.

# %%
# Ask how many sweets there are in total
sweets = int(input("How many sweets are there? "))

# Ask how many pupils are present
pupils = int(input("How many pupils are there? "))

# Calculate how many sweets each pupil gets
each = sweets // pupils

# Calculate how many sweets are left over
leftover = sweets % pupils

# Display the results
print(f"Each pupil gets {each} sweets.")
print(f"There will be {leftover} sweets left over.")
# Out:
# Each pupil gets 0 sweets.
# There will be 7 sweets left over.
